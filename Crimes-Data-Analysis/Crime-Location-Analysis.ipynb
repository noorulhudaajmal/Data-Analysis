# %%
import pandas as pd
import numpy as np
import folium

# %% [markdown]
# # MAP 1

# %% [markdown]
# ## MARKER MAP OF CRIMES AT MOVIE THEATRE

# %% [markdown]
# The dataset consists of data of all crimes at location: Movie/House Theatre in the city of Chicago for the year 2015.

# %%
theatre_data = pd.read_csv("map1.csv")

# %% [markdown]
# **In order to create a Marker map, we will follow following steps**

# %% [markdown]
#  - Refining the data, so it may not contain any null information for the location data

# %%
theatre_data = theatre_data.dropna(axis=0, subset=['Latitude','Longitude'])

# %% [markdown]
# - In order to introduce various icons for the makers; every crime is mapped to some unique icon based on its type. It is done using dataframe mapping to dictionary.
# - To distinguish the crimes based on **Arrest** nature, markers are mapped to have different colors.(using dataframe map function)

# %%
colors = {True:"beige" , False:"red"}
theatre_data["Color"] = theatre_data.Arrest.map(colors)

icons = {'ASSAULT' : "hand-back-fist",
 'BATTERY':"car-battery",
 'BURGLARY':"house-person-return",
 'CRIMINAL DAMAGE':"circle-exclamation",
 'CRIMINAL TRESPASS':"minus",
 'DECEPTIVE PRACTICE':"user-ninja",
 'LIQUOR LAW VIOLATION':"gavel",
 'OTHER OFFENSE':"circle-exclamation",
 'SEX OFFENSE':"people-robbery",
 'THEFT':"sack-dollar"}
theatre_data["Icon"] = theatre_data["Primary Type"].map(icons)

# %% [markdown]
# - This step involves
# -- Creating folium map object
# -- Then inserting markers into it using information from the dataframe
# -- Adding a popup to every column containing information/description of the crime.

# %%
map = folium.Map(location=[theatre_data.Latitude.mean(), theatre_data.Longitude.mean()], 
                 zoom_start=12, control_scale=True)

#Loop through each row in the dataframe
for i,row in theatre_data.iterrows():
    #Setup the content of the popup
    iframe = folium.IFrame('Crime Type: ' + "<b>"+str(row["Primary Type"])
                           +"</b>" + "<br>(" + str(row["Description"])+")<br>"
                           + "<br>"+ "Date: " + str(row["Date"])
                          + "<br>"+ "Arrest Status: " + str(row["Arrest"])
                          + "<br>"+ "Community Area # " + str(row["Community Area"])+"<br>")
    
    #Initialise the popup using the iframe
    popup = folium.Popup(iframe, min_width=300, max_width=300)
    
    #Add each row to the map
    folium.Marker(location=[row['Latitude'],row['Longitude']],icon=folium.Icon(color=row['Color'], icon=row["Icon"],prefix='fa'),
                  popup = popup, c=row['Date']).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3260715df992881b4b23e93d2e4a7a4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3260715df992881b4b23e93d2e4a7a4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3260715df992881b4b23e93d2e4a7a4d = L.map(
#                 &quot;map_3260715df992881b4b23e93d2e4a7a4d&quot;,
#                 {
#                     center: [41.89393522759553, -87.67327460393258],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3260715df992881b4b23e93d2e4a7a4d);
#
#
#
#
#
#             var tile_layer_1452487c7abfefb591d167d80870f43c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3260715df992881b4b23e93d2e4a7a4d);
#
#
#             var marker_13a17ebf73909b73052cc9f4326f49a7 = L.marker(
#                 [41.892753031, -87.624193896],
#                 {&quot;c&quot;: &quot;09/17/2015 08:25:00 PM&quot;}
#             ).addTo(map_3260715df992881b4b23e93d2e4a7a4d);
#
#
#             var icon_88c1caf991fae9ca43f246c1139bb15e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;car-battery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_13a17ebf73909b73052cc9f4326f49a7.setIcon(icon_88c1caf991fae9ca43f246c1139bb15e);
#
#
#         var popup_ec9c66ac2f112faf2168306795fedab7 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_1edb9c3d87ee27a80850cccd5a5dabd9 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBDcmltZSBUeXBlOiA8Yj5CQVRURVJZPC9iPjxicj4oU0lNUExFKTxicj48YnI+RGF0ZTogMDkvMTcvMjAxNSAwODoyNTowMCBQTTxicj5BcnJlc3QgU3RhdHVzOiBGYWxzZTxicj5Db21tdW5pdHkgQXJlYSAjIDg8YnI+&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_ec9c66ac2f112faf2168306795fedab7.setContent(i_frame_1edb9c3d87ee27a80850cccd5a5dabd9);
#
#
#
#         marker_13a17ebf73909b73052cc9f4326f49a7.bindPopup(popup_ec9c66ac2f112faf2168306795fedab7)
#         ;
#
#
#
#
#             var marker_0225a6a644cd757d957ff8d3e4ab0d83 = L.marker(
#                 [41.969571632, -87.659684501],
#                 {&quot;c&quot;: &quot;09/20/2015 02:18:00 AM&quot;}
#             ).addTo(map_3260715df992881b4b23e93d2e4a7a4d);
#
#
#             var icon_7aaea1e3b318c0027f8d0511884ab9de = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;minus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0225a6a644cd757d957ff8d3e4ab0d83.setIcon(icon_7aaea1e3b318c0027f8d0511884ab9de);
#
#
#         var popup_fbf115fdab34f573cf613a5c30cfc8f7 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_63ce1b8984738d1285e6e2cfc44fbadb = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBDcmltZSBUeXBlOiA8Yj5DUklNSU5BTCBUUkVTUEFTUzwvYj48YnI+KFRPIExBTkQpPGJyPjxicj5EYXRlOiAwOS8yMC8yMDE1IDAyOjE4OjAwIEFNPGJyPkFycmVzdCBTdGF0dXM6IFRydWU8YnI+Q29tbXVuaXR5IEFyZWEgIyAzPGJyPg==&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_fbf115fdab34f573cf613a5c30cfc8f7.setContent(i_frame_63ce1b8984738d1285e6e2cfc44fbadb);
#
#
#
#         marker_0225a6a644cd757d957ff8d3e4ab0d83.bindPopup(popup_fbf115fdab34f573cf613a5c30cfc8f7)
#         ;
#
#
#
#
#             var marker_4be0fb13b056d73666cdfb36912ced36 = L.marker(
#                 [41.939286479, -87.654085821],
#                 {&quot;c&quot;: &quot;09/25/2015 09:00:00 PM&quot;}
#             ).addTo(map_3260715df992881b4b23e93d2e4a7a4d);
#
#
#             var icon_3763ab17e730efdb04f89df7c86ff147 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;gavel&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4be0fb13b056d73666cdfb36912ced36.setIcon(icon_3763ab17e730efdb04f89df7c86ff147);
#
#
#         var popup_691bc393b0daa277bc1ea693f726bf09 = L.popup({&quot;m

# %% [markdown]
# # MAP 2

# %% [markdown]
# ## CLUSTER MAP OF GAMBLING CRIMES

# %%
from folium.plugins import MarkerCluster

# %% [markdown]
# The dataset consists of data of all Gambling crimes in the city of Chicago for the year 2015.

# %%
gambling_data = pd.read_csv("map2.csv")

# %% [markdown]
# - At first, a map object is created with a location centered at mean location of the data

# %%
gambling_map = folium.Map(location=[gambling_data.Latitude.mean(), gambling_data.Longitude.mean()], 
                 zoom_start=12, control_scale=True
)

# %% [markdown]
# - Then a cluster layer is added to include the crimes closer to each other in one cluster.
# -- popup contains related description of the crime.
# -- layer is added to map object sing layer control.

# %%
gamblings = MarkerCluster(name="Gambling Crimes").add_to(gambling_map)
for i,row in gambling_data.iterrows():
    #Setup the content of the popup
    iframe = folium.IFrame('Crime Type: ' + "<b>"+str(row["Primary Type"])
                           +"</b>" + "<br>(" + str(row["Description"])+")<br>"
                           + "<br>"+ "Date: " + str(row["Date"])
                           + "<br>"+ "Location: " + str(row["Location Description"])
                          + "<br>"+ "Arrest Status: " + str(row["Arrest"])
                          + "<br>"+ "Community Area # " + str(row["Community Area"])+"<br>")
    
    #Initialise the popup using the iframe
    popup = folium.Popup(iframe, min_width=300, max_width=300)
    
    folium.Marker(location=[row['Latitude'],row['Longitude']],
                  popup=popup).add_to(gamblings)

folium.LayerControl().add_to(gambling_map)
gambling_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1e2cff655227516c16e0f9e14df4de2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1e2cff655227516c16e0f9e14df4de2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1e2cff655227516c16e0f9e14df4de2 = L.map(
#                 &quot;map_d1e2cff655227516c16e0f9e14df4de2&quot;,
#                 {
#                     center: [41.82585967133548, -87.68418479003228],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d1e2cff655227516c16e0f9e14df4de2);
#
#
#
#
#
#             var tile_layer_be7521fdf6be96be80aaf0bce7473234 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d1e2cff655227516c16e0f9e14df4de2);
#
#
#             var marker_cluster_22d005f06181243db9a70fd695d5d1c6 = L.markerClusterGroup(
#                 {}
#             );
#             map_d1e2cff655227516c16e0f9e14df4de2.addLayer(marker_cluster_22d005f06181243db9a70fd695d5d1c6);
#
#
#             var marker_cae9a9f6f0417d13e9ce5760eec30367 = L.marker(
#                 [41.78631519, -87.63332122],
#                 {}
#             ).addTo(marker_cluster_22d005f06181243db9a70fd695d5d1c6);
#
#
#         var popup_f2df553c123a86968fbf1a0810ca4bd4 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_82bf415928ecef82ea5590acd22af2ac = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBDcmltZSBUeXBlOiA8Yj5HQU1CTElORzwvYj48YnI+KEdBTUUvRElDRSk8YnI+PGJyPkRhdGU6IDA5LzA1LzIwMTUgMTE6NTU6MDAgUE08YnI+TG9jYXRpb246IFNJREVXQUxLPGJyPkFycmVzdCBTdGF0dXM6IFRydWU8YnI+Q29tbXVuaXR5IEFyZWEgIyA2ODxicj4=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_f2df553c123a86968fbf1a0810ca4bd4.setContent(i_frame_82bf415928ecef82ea5590acd22af2ac);
#
#
#
#         marker_cae9a9f6f0417d13e9ce5760eec30367.bindPopup(popup_f2df553c123a86968fbf1a0810ca4bd4)
#         ;
#
#
#
#
#             var marker_aa1ceba661d02548c2d5253af6587b6f = L.marker(
#                 [41.77738398, -87.64080579],
#                 {}
#             ).addTo(marker_cluster_22d005f06181243db9a70fd695d5d1c6);
#
#
#         var popup_c4a496471d2731a3775e989efeb0bc57 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_1a13f69a07a4e5beb9f51e5261aea6d7 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBDcmltZSBUeXBlOiA8Yj5HQU1CTElORzwvYj48YnI+KEdBTUUvRElDRSk8YnI+PGJyPkRhdGU6IDA5LzA2LzIwMTUgMTE6NDQ6MDAgQU08YnI+TG9jYXRpb246IFNJREVXQUxLPGJyPkFycmVzdCBTdGF0dXM6IFRydWU8YnI+Q29tbXVuaXR5IEFyZWEgIyA2ODxicj4=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_c4a496471d2731a3775e989efeb0bc57.setContent(i_frame_1a13f69a07a4e5beb9f51e5261aea6d7);
#
#
#
#         marker_aa1ceba661d02548c2d5253af6587b6f.bindPopup(popup_c4a496471d2731a3775e989efeb0bc57)
#         ;
#
#
#
#
#             var marker_5d40ff70da6ba025212fb9d56bd355ba = L.marker(
#                 [41.859913531, -87.723771229],
#                 {}
#             ).addTo(marker_cluster_22d005f06181243db9a70fd695d5d1c6);
#
#
#         var popup_de84884ac47eacb5e2120a7cf36002d8 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_1b3d407ae5738bdd6698ef9d66a7a009 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBDcmltZSBUeXBlOiA8Yj5HQU1CTElORzwvYj48YnI+KEdBTUUvRElDRSk8YnI+PGJyPkRhdGU6IDA5LzA2LzIwMTUgMDg6NDU6MDAgUE08YnI+TG9jYXRpb246IFNJREVXQUxLPGJyPkFycmVzdCBTdGF0dXM6IFRydWU8YnI+Q29tbXVuaXR5IEFyZWEgIyAyOTxicj4=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];

# %% [markdown]
# # MAP 3

# %% [markdown]
# ## HEATMAP OF ARSON CRIMES

# %%
from folium import plugins
from folium.plugins import HeatMap

# %%
arson_data = pd.read_csv("map3.csv")

# %% [markdown]
# The dataset consists of data of all **ARSON** crimes in the city of Chicago for the year 2015.

# %% [markdown]
# - At first, data is refined to drop the null values of location

# %%
arson_data = arson_data.dropna(axis=0, subset=['Latitude','Longitude'])

# %% [markdown]
# - Then a map object is created with location centered at mean location value from data
# -- Then upon iterating over data, Heatmap will be created to include in the map object.

# %%
arson_map = folium.Map(location=[arson_data.Latitude.mean(), arson_data.Longitude.mean()],
                    zoom_start = 12,control_scale=True)
heat_data = [[row['Latitude'],row['Longitude']] for index, row in arson_data.iterrows()]

# Plot it on the map
HeatMap(heat_data).add_to(arson_map)

# Display the map
arson_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_123ce8493e7cfc1dcb68b929ee8b9604 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_123ce8493e7cfc1dcb68b929ee8b9604&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_123ce8493e7cfc1dcb68b929ee8b9604 = L.map(
#                 &quot;map_123ce8493e7cfc1dcb68b929ee8b9604&quot;,
#                 {
#                     center: [41.833000754580574, -87.67613731326274],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_123ce8493e7cfc1dcb68b929ee8b9604);
#
#
#
#
#
#             var tile_layer_a8637231cf0b8abbdaebda36afd9d03a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_123ce8493e7cfc1dcb68b929ee8b9604);
#
#
#             var heat_map_cd43ce6d6bef07866b0407b85ceaf384 = L.heatLayer(
#                 [[41.767610987, -87.672391655], [41.898219905, -87.733559614], [41.734771251, -87.608454453], [41.764179084, -87.665011627], [41.876268094, -87.745118351], [41.745402793, -87.591698509], [41.78054353, -87.718616915], [41.889787714, -87.763364941], [41.858875982, -87.724247284], [41.899176885, -87.64304338], [41.731822765, -87.643493574], [41.696554057, -87.647382098], [41.742786344, -87.573466009], [41.737153061, -87.657022401], [41.850874122, -87.722256753], [41.847564182, -87.72788903], [41.814887983, -87.689506618], [41.914811725, -87.695895576], [41.919569733, -87.781659187], [41.743125083, -87